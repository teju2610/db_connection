# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\CVR\\Downloads\\customer_data.csv")
df.head()
# Out:
#    Customer_ID  Age  Gender  Income  Purchase_History  Last_Purchase_Amount  \
# 0         1001   25    Male   45000                 5                   120
# 1         1002   34  Female   54000                 8                   300
# 2         1003   45    Male   62000                12                   450
# 3         1004   23  Female   38000                 3                    75
# 4         1005   54    Male   78000                15                   600
#
#    Loyalty_Score
# 0             78
# 1             85
# 2             90
# 3             65
# 4             95

# %%
df.drop(columns=['Purchase_History'])
# Out:
#    Customer_ID  Age  Gender  Income  Last_Purchase_Amount  Loyalty_Score
# 0         1001   25    Male   45000                   120             78
# 1         1002   34  Female   54000                   300             85
# 2         1003   45    Male   62000                   450             90
# 3         1004   23  Female   38000                    75             65
# 4         1005   54    Male   78000                   600             95
# 5         1006   31   Other   50000                   230             80
# 6         1007   40  Female   67000                   500             88
# 7         1008   29    Male   48000                   150             70
# 8         1009   37  Female   52000                   320             82
# 9         1010   50    Male   71000                   590             93

# %%
df=pd.read_csv("C:\\Users\\CVR\\Downloads\\tested.csv")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
d=df['Survived']
d
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    1
# 415    0
# 416    0
# 417    0
# Name: Survived, Length: 418, dtype: int64

# %%
numerical_cols=df.select_dtypes(include=['number'])
y=numerical_cols['Survived']
x=numerical_cols.drop(columns='Survived',axis=1)
x.corr().round(2)
# Out:
#              PassengerId  Pclass   Age  SibSp  Parch  Fare
# PassengerId         1.00   -0.03 -0.03   0.00   0.04  0.01
# Pclass             -0.03    1.00 -0.49   0.00   0.02 -0.58
# Age                -0.03   -0.49  1.00  -0.09  -0.06  0.34
# SibSp               0.00    0.00 -0.09   1.00   0.31  0.17
# Parch               0.04    0.02 -0.06   0.31   1.00  0.23
# Fare                0.01   -0.58  0.34   0.17   0.23  1.00

# %%
import seaborn as sns

# %%
sns.heatmap(x.corr().round(2),annot=True,cmap='magma')
# Out:
# <Axes: >

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
data = {'Difficulty': ['Easy', 'Medium', 'Hard', 'Medium', 'Easy'],
        'Test Score': [50, 60, 70, 80, 90]}
df=pd.DataFrame(data)
encoder=LabelEncoder()
df['Difficulty_encoded']=encoder.fit_transform(df['Difficulty'])
print(df)
correlation=df['Difficulty_encoded'].corr(df['Test Score'])
print("Correlation",correlation)
# Out:
#   Difficulty  Test Score  Difficulty_encoded
# 0       Easy          50                   0
# 1     Medium          60                   2
# 2       Hard          70                   1
# 3     Medium          80                   2
# 4       Easy          90                   0
# Correlation 0.0

# %%
data={'Color':['Red','Blue','Green','Blue','Red'],
     'Test Score':[50,60,70,80,90]}
df=pd.DataFrame(data)
df_encoded=pd.get_dummies(df,columns=['Color'])
print(df_encoded)
correlation=df_encoded['Color_Red'].corr(df_encoded['Test Score'])
print(correlation)
# Out:
#    Test Score  Color_Blue  Color_Green  Color_Red
# 0          50       False        False       True
# 1          60        True        False      False
# 2          70       False         True      False
# 3          80        True        False      False
# 4          90       False        False       True
# -1.2819751242557094e-17
